# %% [markdown]
# ## Loading libraries

# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import time
import lightgbm as lgbm
from pathlib import Path
import pickle
from catboost import CatBoostClassifier, cv, Pool
import scikitplot as skplt
from hyperopt import tpe, STATUS_OK, Trials, hp, fmin, tpe, partial

import itertools
from itertools import combinations

import scipy as sp
from scipy.stats import pearsonr, chi2_contingency

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap

from datetime import datetime
from dateutil import relativedelta

from IPython.display import display
pd.options.display.max_columns = None
pd.options.display.max_colwidth = None
pd.options.display.max_rows = None

import statsmodels.api as sm 
from statsmodels.graphics.api import abline_plot # For visualling evaluating predictions.
from statsmodels.stats.proportion import proportion_confint

import warnings # For handling error messages.
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.filterwarnings('ignore')

import sklearn.metrics as met
from sklearn import linear_model, preprocessing, model_selection, svm, datasets
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel, SelectKBest, chi2, RFE
from sklearn.linear_model import LassoCV, LogisticRegression, Lasso
from sklearn.metrics import plot_confusion_matrix, auc, confusion_matrix, classification_report, accuracy_score, roc_curve, roc_auc_score, plot_roc_curve
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import scale, StandardScaler, LabelEncoder, MinMaxScaler, Binarizer
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from bayes_opt import BayesianOptimization
from bayes_opt.logger import JSONLogger
from bayes_opt.event import Events
from bayes_opt.util import load_logs

# %% [markdown]
# ## Loading dataset

# %%
df = pd.read_csv('df1.csv', index_col='id')

# %% [markdown]
# ### First looks.

# %%
df.head()
# Out:
#           member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 68407277        NaN     3600.0       3600.0           3600.0   36 months
# 68355089        NaN    24700.0      24700.0          24700.0   36 months
# 68341763        NaN    20000.0      20000.0          20000.0   60 months
# 68476807        NaN    10400.0      10400.0          10400.0   60 months
# 68426831        NaN    11950.0      11950.0          11950.0   36 months
#
#           int_rate  installment grade sub_grade             emp_title  \
# id
# 68407277     13.99       123.03     C        C4               leadman
# 68355089     11.99       820.28     C        C1              Engineer
# 68341763     10.78       432.66     B        B4          truck driver
# 68476807     22.45       289.91     F        F1   Contract Specialist
# 68426831     13.44       405.18     C        C3  Veterinary Tecnician
#
#          emp_length home_ownership  annual_inc verification_status   issue_d  \
# id
# 68407277  10+ years       MORTGAGE     55000.0        Not Verified  Dec-2015
# 68355089  10+ years       MORTGAGE     65000.0        Not Verified  Dec-2015
# 68341763  10+ years       MORTGAGE     63000.0        Not Verified  Dec-2015
# 68476807    3 years       MORTGAGE    104433.0     Source Verified  Dec-2015
# 68426831    4 years           RENT     34000.0     Source Verified  Dec-2015
#
#          loan_status pymnt_plan  \
# id
# 68407277  Fully Paid          n
# 68355089  Fully Paid          n
# 68341763  Fully Paid          n
# 68476807  Fully Paid          n
# 68426831  Fully Paid          n
#
#                                                                         url  \
# id
# 68407277  https://lendingclub.com/browse/loanDetail.action?loan_id=68407277
# 68355089  https://lendingclub.com/browse/loanDetail.action?loan_id=68355089
# 68341763  https://lendingclub.com/browse/loanDetail.action?loan_id=68341763
# 68476807  https://lendingclub.com/browse/loanDetail.action?loan_id=68476807
# 68426831  https://lendingclub.com/browse/loanDetail.action?loan_id=68426831
#
#          desc             purpose               title zip_code addr_state  \
# id
# 68407277  NaN  debt_consolidation  Debt consolidation    190xx         PA
# 68355089  NaN      small_business            Business    577xx         SD
# 68341763  NaN    home_improvement                 NaN    605xx         IL
# 68476807  NaN      major_purchase      Major purchase    174xx         PA
# 68426831  NaN  debt_consolidation  Debt consolidation    300xx         GA
#
#             dti  delinq_2yrs earliest_cr_line  fico_range_low  \
# id
# 68407277   5.91          0.0         Aug-2003           675.0
# 68355089  16.06          1.0         Dec-1999           715.0
# 68341763  10.78          0.0         Aug-2000           695.0
# 68476807  25.37          1.0         Jun-1998           695.0
# 68426831  10.20          0.0         Oct-1987           690.0
#
#           fico_range_high  inq_last_6mths  mths_since_last_delinq  \
# id
# 68407277            679.0             1.0                    30.0
# 68355089            719.0             4.0                     6.0
# 68341763            699.0             0.0                     NaN
# 68476807            699.0             3.0                    12.0
# 68426831            694.0             0.0                     NaN
#
#           mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# id
# 68407277                     NaN       7.0      0.0     2765.0        29.7
# 68355089                     NaN      22.0      0.0    21470.0        19.2
# 68341763                     NaN       6.0      0.0     7869.0        56.2
# 68476807                     NaN      12.0      0.0    21929.0        64.5
# 68426831                     NaN       5.0      0.0     8822.0        68.4
#
#           total_acc initial_list_status  out_prncp  out_prncp_inv  \
# id
# 68407277       13.0                   w        0.0            0.0
# 68355089       38.0                   w        0.0            0.0
# 68341763       18.0                   w        0.0            0.0
# 68476807       35.0                   w        0.0            0.0
# 68426831        6.0                   w        0.0            0.0
#
#            total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# id
# 68407277   4421.723917          4421.72           3600.0         821.72
# 68355089  25679.660000         25679.66          24700.0         979.66
# 68341763  22705.924294         22705.92          20000.0        2705.92
# 68476807  11740.500000         11740.50          10400.0        1340.50
# 68426831  13708.948530         13708.95          11950.0        1758.95
#
#           total_rec_late_fee  recoveries  collection_recovery_fee  \
# id
# 68407277                 0.0         0.0                      0.0
# 68355089                 0.0         0.0                      0.0
# 68341763                 0.0         0.0                      0.0
# 68476807                 0.0         0.0                      0.0
# 68426831                 0.0         0.0                      0.0
#
#          last_pymnt_d  last_pymnt_amnt  next_pymnt_d last_credit_pull_d  \
# id
# 68407277     Jan-2019           122.67           NaN           Mar-2019
# 68355089     Jun-2016           926.35           NaN           Mar-2019
# 68341763     Jun-2017         15813.30           NaN           Mar-2019
# 68476807     Jul-2016         10128.96           NaN           Mar-2018
# 68426831     May-2017          7653.56           NaN           May-2017
#
#           last_fico_range_high  last_fico_range_low  \
# id
# 68407277                 564.0                560.0
# 68355089                 699.0                695.0
# 68341763                 704.0                700.0
# 68476807                 704.0                700.0
# 68426831                 759.0                755.0
#
#           collections_12_mths_ex_med  mths_since_last_major_derog  \
# id
# 68407277                         0.0                         30.0
# 68355089                         0.0                          NaN
# 68341763                         0.0                          NaN
# 68476807                         0.0                          NaN
# 68426831                         0.0                          NaN
#
#           policy_code application_type  annual_inc_joint  dti_joint  \
# id
# 68407277          1.0       Individual               NaN        NaN
# 68355089          1.0       Individual               NaN        NaN
# 68341763          1.0        Joint App           71000.0      13.85
# 68476807          1.0       Individual               NaN        NaN
# 68426831          1.0       Individual               NaN        NaN
#
#          verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# id
# 68407277                       NaN             0.0         722.0     144904.0
# 68355089                       NaN             0.0           0.0     204396.0
# 68341763              Not Verified             0.0           0.0     189699.0
# 68476807                       NaN             0.0           0.0     331730.0
# 68426831                       NaN             0.0           0.0      12798.0
#
#           open_acc_6m  open_act_il  open_il_12m  open_il_24m  \
# id
# 68407277          2.0          2.0          0.0          1.0
# 68355089          1.0          1.0          0.0          1.0
# 68341763          0.0          1.0          0.0          4.0
# 68476807          1.0          3.0          0.0          3.0
# 68426831          0.0          1.0          0.0          0.0
#
#           mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  open_rv_24m  \
# id
# 68407277                21.0        4981.0     36.0          3.0          3.0
# 68355089                19.0       18005.0     73.0          2.0          3.0
# 68341763                19.0       10827.0     73.0          0.0          2.0
# 68476807                14.0       73839.0     84.0          4.0          7.0
# 68426831               338.0        3976.0     99.0          0.0          0.0
#
#           max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# id
# 68407277       722.0      34.0            9300.0     3.0          1.0
# 68355089      6472.0      29.0          111800.0     0.0          0.0
# 68341763      2081.0      65.0           14000.0     2.0          5.0
# 68476807      9702.0      78.0           34000.0     2.0          1.0
# 68426831      4522.0      76.0           12900.0     0.0          0.0
#
#           inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  \
# id
# 68407277           4.0                   4.0      20701.0          1506.0
# 68355089           6.0                   4.0       9733.0         57830.0
# 68341763           1.0                   6.0      31617.0          2737.0
# 68476807           3.0                  10.0      27644.0          4567.0
# 68426831           0.0                   0.0       2560.0           844.0
#
#           bc_util  chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# id
# 68407277     37.2                       0.0          0.0               148.0
# 68355089     27.1                       0.0          0.0               113.0
# 68341763     55.9                       0.0          0.0               125.0
# 68476807     77.5                       0.0          0.0               128.0
# 68426831     91.0                       0.0          0.0               338.0
#
#           mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  \
# id
# 68407277                 128.0                    3.0             3.0
# 68355089                 192.0                    2.0             2.0
# 68341763                 184.0                   14.0            14.0
# 68476807                 210.0                    4.0             4.0
# 68426831                  54.0                   32.0            32.0
#
#           mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# id
# 68407277       1.0                   4.0                      69.0
# 68355089       4.0                   2.0                       NaN
# 68341763       5.0                 101.0                       NaN
# 68476807       6.0                   4.0                      12.0
# 68426831       0.0                  36.0                       NaN
#
#           mths_since_recent_inq  mths_since_recent_revol_delinq  \
# id
# 68407277                    4.0                            69.0
# 68355089                    0.0                             6.0
# 68341763                   10.0                             NaN
# 68476807                    1.0                            12.0
# 68426831                    NaN                             NaN
#
#           num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# id
# 68407277                    2.0             2.0              4.0          2.0
# 68355089                    0.0             5.0              5.0         13.0
# 68341763                    0.0             2.0              3.0          2.0
# 68476807                    0.0             4.0              6.0          5.0
# 68426831                    0.0             2.0              3.0          2.0
#
#           num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  \
# id
# 68407277        5.0        3.0            4.0            9.0
# 68355089       17.0        6.0           20.0           27.0
# 68341763        4.0        6.0            4.0            7.0
# 68476807        9.0       10.0            7.0           19.0
# 68426831        2.0        2.0            4.0            4.0
#
#           num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  num_tl_30dpd  \
# id
# 68407277                  4.0       7.0               0.0           0.0
# 68355089                  5.0      22.0               0.0           0.0
# 68341763                  3.0       6.0               0.0           0.0
# 68476807                  6.0      12.0               0.0           0.0
# 68426831                  3.0       5.0               0.0           0.0
#
#           num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# id
# 68407277                 0.0                 3.0            76.9
# 68355089                 0.0                 2.0            97.4
# 68341763                 0.0                 0.0           100.0
# 68476807                 0.0                 4.0            96.6
# 68426831                 0.0                 0.0           100.0
#
#           percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# id
# 68407277               0.0                   0.0        0.0         178050.0
# 68355089               7.7                   0.0        0.0         314017.0
# 68341763              50.0                   0.0        0.0         218418.0
# 68476807              60.0                   0.0        0.0         439570.0
# 68426831             100.0                   0.0        0.0          16900.0
#
#           total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# id
# 68407277             7746.0          2400.0                     13734.0
# 68355089            39475.0         79300.0                     24667.0
# 68341763            18696.0          6200.0                     14877.0
# 68476807            95768.0         20300.0                     88097.0
# 68426831            12798.0          9400.0                      4000.0
#
#           revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# id
# 68407277              NaN                     NaN                      NaN
# 68355089              NaN                     NaN                      NaN
# 68341763              NaN                     NaN                      NaN
# 68476807              NaN                     NaN                      NaN
# 68426831              NaN                     NaN                      NaN
#
#          sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# id
# 68407277                      NaN                     NaN               NaN
# 68355089                      NaN                     NaN               NaN
# 68341763                      NaN                     NaN               NaN
# 68476807                      NaN                     NaN               NaN
# 68426831                      NaN                     NaN               NaN
#
#           sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# id
# 68407277               NaN                 NaN                  NaN
# 68355089               NaN                 NaN                  NaN
# 68341763               NaN                 NaN                  NaN
# 68476807               NaN                 NaN                  NaN
# 68426831               NaN                 NaN                  NaN
#
#           sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# id
# 68407277                    NaN                               NaN
# 68355089                    NaN                               NaN
# 68341763                    NaN                               NaN
# 68476807                    NaN                               NaN
# 68426831                    NaN                               NaN
#
#           sec_app_collections_12_mths_ex_med  \
# id
# 68407277                                 NaN
# 68355089                                 NaN
# 68341763                                 NaN
# 68476807                                 NaN
# 68426831                                 NaN
#
#           sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# id
# 68407277                                  NaN             N           NaN
# 68355089                                  NaN             N           NaN
# 68341763                                  NaN             N           NaN
# 68476807                                  NaN             N           NaN
# 68426831                                  NaN             N           NaN
#
#          hardship_reason hardship_status  deferral_term  hardship_amount  \
# id
# 68407277             NaN             NaN            NaN              NaN
# 68355089             NaN             NaN            NaN              NaN
# 68341763             NaN             NaN            NaN              NaN
# 68476807             NaN             NaN            NaN              NaN
# 68426831             NaN             NaN            NaN              NaN
#
#          hardship_start_date hardship_end_date payment_plan_start_date  \
# id
# 68407277                 NaN               NaN                     NaN
# 68355089                 NaN               NaN                     NaN
# 68341763                 NaN               NaN                     NaN
# 68476807                 NaN               NaN                     NaN
# 68426831                 NaN               NaN                     NaN
#
#           hardship_length  hardship_dpd hardship_loan_status  \
# id
# 68407277              NaN           NaN                  NaN
# 68355089              NaN           NaN                  NaN
# 68341763              NaN           NaN                  NaN
# 68476807              NaN           NaN                  NaN
# 68426831              NaN           NaN                  NaN
#
#           orig_projected_additional_accrued_interest  \
# id
# 68407277                                         NaN
# 68355089                                         NaN
# 68341763                                         NaN
# 68476807                                         NaN
# 68426831                                         NaN
#
#           hardship_payoff_balance_amount  hardship_last_payment_amount  \
# id
# 68407277                             NaN                           NaN
# 68355089                             NaN                           NaN
# 68341763                             NaN                           NaN
# 68476807                             NaN                           NaN
# 68426831                             NaN                           NaN
#
#          disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# id
# 68407277                Cash                    N                       NaN
# 68355089                Cash                    N                       NaN
# 68341763                Cash                    N                       NaN
# 68476807                Cash                    N                       NaN
# 68426831                Cash                    N                       NaN
#
#          settlement_status settlement_date  settlement_amount  \
# id
# 68407277               NaN             NaN                NaN
# 68355089               NaN             NaN                NaN
# 68341763               NaN             NaN                NaN
# 68476807               NaN             NaN                NaN
# 68426831               NaN             NaN                NaN
#
#           settlement_percentage  settlement_term
# id
# 68407277                    NaN              NaN
# 68355089                    NaN              NaN
# 68341763                    NaN              NaN
# 68476807                    NaN              NaN
# 68426831                    NaN              NaN

# %%
df.tail()
# Out:
#           member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 89905081        NaN    18000.0      18000.0          18000.0   60 months
# 88948836        NaN    29400.0      29400.0          29400.0   60 months
# 89996426        NaN    32000.0      32000.0          32000.0   60 months
# 90006534        NaN    16000.0      16000.0          16000.0   60 months
# 88224441        NaN    24000.0      24000.0          24000.0   60 months
#
#           int_rate  installment grade sub_grade                emp_title  \
# id
# 89905081      9.49       377.95     B        B2                      NaN
# 88948836     13.99       683.94     C        C3  Chief Operating Officer
# 89996426     14.49       752.74     C        C4            Sales Manager
# 90006534     12.79       362.34     C        C1                  Manager
# 88224441     14.49       564.56     C        C4          Program Manager
#
#          emp_length home_ownership  annual_inc verification_status   issue_d  \
# id
# 89905081    5 years            OWN    130000.0        Not Verified  Oct-2016
# 88948836    9 years       MORTGAGE    180792.0        Not Verified  Oct-2016
# 89996426    3 years       MORTGAGE    157000.0     Source Verified  Oct-2016
# 90006534  10+ years           RENT    150000.0        Not Verified  Oct-2016
# 88224441    6 years           RENT    110000.0        Not Verified  Oct-2016
#
#           loan_status pymnt_plan  \
# id
# 89905081   Fully Paid          n
# 88948836   Fully Paid          n
# 89996426  Charged Off          n
# 90006534   Fully Paid          n
# 88224441  Charged Off          n
#
#                                                                         url  \
# id
# 89905081  https://lendingclub.com/browse/loanDetail.action?loan_id=89905081
# 88948836  https://lendingclub.com/browse/loanDetail.action?loan_id=88948836
# 89996426  https://lendingclub.com/browse/loanDetail.action?loan_id=89996426
# 90006534  https://lendingclub.com/browse/loanDetail.action?loan_id=90006534
# 88224441  https://lendingclub.com/browse/loanDetail.action?loan_id=88224441
#
#          desc             purpose               title zip_code addr_state  \
# id
# 89905081  NaN    home_improvement    Home improvement    775xx         TX
# 88948836  NaN  debt_consolidation  Debt consolidation    900xx         CA
# 89996426  NaN    home_improvement    Home improvement    863xx         AZ
# 90006534  NaN             medical    Medical expenses    284xx         NC
# 88224441  NaN  debt_consolidation  Debt consolidation    334xx         FL
#
#             dti  delinq_2yrs earliest_cr_line  fico_range_low  \
# id
# 89905081  20.59          0.0         Jul-2004           735.0
# 88948836  22.03          0.0         Mar-2002           705.0
# 89996426  10.34          0.0         Jun-2011           735.0
# 90006534  12.25          0.0         Aug-1997           665.0
# 88224441  18.30          0.0         Jul-1999           660.0
#
#           fico_range_high  inq_last_6mths  mths_since_last_delinq  \
# id
# 89905081            739.0             1.0                     NaN
# 88948836            709.0             1.0                     NaN
# 89996426            739.0             0.0                     NaN
# 90006534            669.0             0.0                    68.0
# 88224441            664.0             0.0                    67.0
#
#           mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# id
# 89905081                     NaN      17.0      0.0    23833.0        34.0
# 88948836                     NaN      16.0      0.0    77480.0        85.2
# 89996426                     NaN      14.0      0.0   111598.0        27.4
# 90006534                    26.0      12.0      4.0     7700.0        55.0
# 88224441                    72.0      10.0      1.0    17641.0        68.1
#
#           total_acc initial_list_status  out_prncp  out_prncp_inv  \
# id
# 89905081       39.0                   f        0.0            0.0
# 88948836       32.0                   f        0.0            0.0
# 89996426       18.0                   f        0.0            0.0
# 90006534       28.0                   f        0.0            0.0
# 88224441       31.0                   f        0.0            0.0
#
#            total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# id
# 89905081  20756.233632         20756.23         18000.00        2756.23
# 88948836  35848.764532         35848.76         29400.00        6448.76
# 89996426   3737.940000          3737.94          1876.47        1861.47
# 90006534  18660.607569         18660.61         16000.00        2660.61
# 88224441   6755.400000          6755.40          3521.91        3233.49
#
#           total_rec_late_fee  recoveries  collection_recovery_fee  \
# id
# 89905081                 0.0         0.0                      0.0
# 88948836                 0.0         0.0                      0.0
# 89996426                 0.0         0.0                      0.0
# 90006534                 0.0         0.0                      0.0
# 88224441                 0.0         0.0                      0.0
#
#          last_pymnt_d  last_pymnt_amnt  next_pymnt_d last_credit_pull_d  \
# id
# 89905081     Aug-2018         12828.77           NaN           Mar-2019
# 88948836     Jul-2018         22192.81           NaN           Jul-2018
# 89996426     Mar-2017           752.74           NaN           Dec-2018
# 90006534     Mar-2018         12874.54           NaN           Mar-2019
# 88224441     Oct-2017           564.56           NaN           Mar-2019
#
#           last_fico_range_high  last_fico_range_low  \
# id
# 89905081                 709.0                705.0
# 88948836                 719.0                715.0
# 89996426                 499.0                  0.0
# 90006534                 684.0                680.0
# 88224441                 594.0                590.0
#
#           collections_12_mths_ex_med  mths_since_last_major_derog  \
# id
# 89905081                         0.0                          NaN
# 88948836                         0.0                          NaN
# 89996426                         0.0                          NaN
# 90006534                         0.0                         68.0
# 88224441                         0.0                         67.0
#
#           policy_code application_type  annual_inc_joint  dti_joint  \
# id
# 89905081          1.0       Individual               NaN        NaN
# 88948836          1.0       Individual               NaN        NaN
# 89996426          1.0       Individual               NaN        NaN
# 90006534          1.0       Individual               NaN        NaN
# 88224441          1.0       Individual               NaN        NaN
#
#          verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# id
# 89905081                       NaN             0.0           0.0     168758.0
# 88948836                       NaN             0.0           0.0     663465.0
# 89996426                       NaN             0.0           0.0     408701.0
# 90006534                       NaN             0.0           0.0      65797.0
# 88224441                       NaN             0.0           0.0      62426.0
#
#           open_acc_6m  open_act_il  open_il_12m  open_il_24m  \
# id
# 89905081          0.0          6.0          0.0          3.0
# 88948836          0.0          4.0          2.0          4.0
# 89996426          2.0          2.0          0.0          2.0
# 90006534          1.0          5.0          2.0          6.0
# 88224441          0.0          2.0          0.0          2.0
#
#           mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  open_rv_24m  \
# id
# 89905081                15.0       30516.0     52.0          0.0          3.0
# 88948836                 8.0       70652.0     50.0          0.0          0.0
# 89996426                16.0       11274.0     47.0          2.0          7.0
# 90006534                 4.0       58097.0     79.0          0.0          3.0
# 88224441                20.0       44785.0     78.0          1.0          5.0
#
#           max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# id
# 89905081      7061.0      41.0           70100.0     1.0          2.0
# 88948836     31069.0      68.0           86500.0     3.0          0.0
# 89996426       736.0      36.0          207500.0     2.0          2.0
# 90006534      4516.0      75.0           14000.0     1.0          1.0
# 88224441      6172.0      73.0           25900.0     0.0          0.0
#
#           inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  \
# id
# 89905081           1.0                   6.0       9927.0          4161.0
# 88948836           2.0                   4.0      44231.0          8427.0
# 89996426           0.0                  10.0      29193.0         14118.0
# 90006534           1.0                   9.0       5982.0          2720.0
# 88224441           1.0                   7.0       6243.0          4660.0
#
#           bc_util  chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# id
# 89905081     68.2                       0.0          0.0               113.0
# 88948836     69.4                       0.0          0.0               145.0
# 89996426     10.6                       0.0          0.0                53.0
# 90006534     73.1                       0.0          0.0               147.0
# 88224441     77.5                       0.0          0.0               132.0
#
#           mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  \
# id
# 89905081                 146.0                   17.0            15.0
# 88948836                 174.0                   31.0             8.0
# 89996426                  63.0                    4.0             4.0
# 90006534                 229.0                   17.0             4.0
# 88224441                 206.0                    9.0             9.0
#
#           mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# id
# 89905081       3.0                  17.0                       NaN
# 88948836       3.0                  70.0                       NaN
# 89996426       3.0                   4.0                       NaN
# 90006534       0.0                  17.0                       NaN
# 88224441       2.0                   9.0                       NaN
#
#           mths_since_recent_inq  mths_since_recent_revol_delinq  \
# id
# 89905081                    2.0                             NaN
# 88948836                    3.0                             NaN
# 89996426                   15.0                             NaN
# 90006534                   12.0                             NaN
# 88224441                    9.0                             NaN
#
#           num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# id
# 89905081                    0.0             3.0              9.0          3.0
# 88948836                    0.0             4.0              5.0          7.0
# 89996426                    0.0             5.0              8.0          7.0
# 90006534                    1.0             3.0              4.0          4.0
# 88224441                    1.0             5.0              7.0          5.0
#
#           num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  \
# id
# 89905081        5.0       21.0           10.0           15.0
# 88948836        9.0       17.0            8.0           10.0
# 89996426        7.0        4.0           11.0           11.0
# 90006534        5.0       15.0            6.0           11.0
# 88224441       15.0        4.0            8.0           24.0
#
#           num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  num_tl_30dpd  \
# id
# 89905081                  9.0      17.0               0.0           0.0
# 88948836                  5.0      16.0               0.0           0.0
# 89996426                  8.0      14.0               0.0           0.0
# 90006534                  4.0      12.0               0.0           0.0
# 88224441                  7.0      10.0               0.0           0.0
#
#           num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# id
# 89905081                 0.0                 0.0           100.0
# 88948836                 0.0                 2.0           100.0
# 89996426                 0.0                 2.0           100.0
# 90006534                 0.0                 2.0            92.0
# 88224441                 0.0                 1.0            96.2
#
#           percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# id
# 89905081              33.3                   0.0        0.0         275356.0
# 88948836              42.9                   0.0        0.0         719056.0
# 89996426               0.0                   0.0        0.0         524379.0
# 90006534              50.0                   3.0        0.0          87473.0
# 88224441              40.0                   1.0        0.0          84664.0
#
#           total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# id
# 89905081            54349.0         13100.0                     77756.0
# 88948836           148305.0         56500.0                     95702.0
# 89996426           122872.0         15800.0                     23879.0
# 90006534            65797.0         10100.0                     73473.0
# 88224441            62426.0         20700.0                     58764.0
#
#           revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# id
# 89905081              NaN                     NaN                      NaN
# 88948836              NaN                     NaN                      NaN
# 89996426              NaN                     NaN                      NaN
# 90006534              NaN                     NaN                      NaN
# 88224441              NaN                     NaN                      NaN
#
#          sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# id
# 89905081                      NaN                     NaN               NaN
# 88948836                      NaN                     NaN               NaN
# 89996426                      NaN                     NaN               NaN
# 90006534                      NaN                     NaN               NaN
# 88224441                      NaN                     NaN               NaN
#
#           sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# id
# 89905081               NaN                 NaN                  NaN
# 88948836               NaN                 NaN                  NaN
# 89996426               NaN                 NaN                  NaN
# 90006534               NaN                 NaN                  NaN
# 88224441               NaN                 NaN                  NaN
#
#           sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# id
# 89905081                    NaN                               NaN
# 88948836                    NaN                               NaN
# 89996426                    NaN                               NaN
# 90006534                    NaN                               NaN
# 88224441                    NaN                               NaN
#
#           sec_app_collections_12_mths_ex_med  \
# id
# 89905081                                 NaN
# 88948836                                 NaN
# 89996426                                 NaN
# 90006534                                 NaN
# 88224441                                 NaN
#
#           sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# id
# 89905081                                  NaN             N           NaN
# 88948836                                  NaN             N           NaN
# 89996426                                  NaN             N           NaN
# 90006534                                  NaN             N           NaN
# 88224441                                  NaN             N           NaN
#
#          hardship_reason hardship_status  deferral_term  hardship_amount  \
# id
# 89905081             NaN             NaN            NaN              NaN
# 88948836             NaN             NaN            NaN              NaN
# 89996426             NaN             NaN            NaN              NaN
# 90006534             NaN             NaN            NaN              NaN
# 88224441             NaN             NaN            NaN              NaN
#
#          hardship_start_date hardship_end_date payment_plan_start_date  \
# id
# 89905081                 NaN               NaN                     NaN
# 88948836                 NaN               NaN                     NaN
# 89996426                 NaN               NaN                     NaN
# 90006534                 NaN               NaN                     NaN
# 88224441                 NaN               NaN                     NaN
#
#           hardship_length  hardship_dpd hardship_loan_status  \
# id
# 89905081              NaN           NaN                  NaN
# 88948836              NaN           NaN                  NaN
# 89996426              NaN           NaN                  NaN
# 90006534              NaN           NaN                  NaN
# 88224441              NaN           NaN                  NaN
#
#           orig_projected_additional_accrued_interest  \
# id
# 89905081                                         NaN
# 88948836                                         NaN
# 89996426                                         NaN
# 90006534                                         NaN
# 88224441                                         NaN
#
#           hardship_payoff_balance_amount  hardship_last_payment_amount  \
# id
# 89905081                             NaN                           NaN
# 88948836                             NaN                           NaN
# 89996426                             NaN                           NaN
# 90006534                             NaN                           NaN
# 88224441                             NaN                           NaN
#
#          disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# id
# 89905081                Cash                    N                       NaN
# 88948836                Cash                    N                       NaN
# 89996426                Cash                    N                       NaN
# 90006534                Cash                    N                       NaN
# 88224441                Cash                    Y                  Mar-2019
#
#          settlement_status settlement_date  settlement_amount  \
# id
# 89905081               NaN             NaN                NaN
# 88948836               NaN             NaN                NaN
# 89996426               NaN             NaN                NaN
# 90006534               NaN             NaN                NaN
# 88224441            ACTIVE        Mar-2019            10000.0
#
#           settlement_percentage  settlement_term
# id
# 89905081                    NaN              NaN
# 88948836                    NaN              NaN
# 89996426                    NaN              NaN
# 90006534                    NaN              NaN
# 88224441                  44.82              1.0

# %% [markdown]
# ### 1.3M rows and 151 columns (including index).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1345310 entries, 68407277 to 88224441
# Columns: 150 entries, member_id to settlement_term
# dtypes: float64(114), object(36)
# memory usage: 1.5+ GB

# %% [markdown]
# ### Though it's no longer available on Kaggle, Wendy Kan provided a list of feature descriptions.

# %% [markdown]
# acc_now_delinq	The number of accounts on which the borrower is now delinquent
#
# acc_open_past_24mths	Number of trades opened in past 24 months
#
# addr_state	The state provided by the borrower in the loan application
#
# all_util	Balance to credit limit on all trades
#
# annual_inc	The self-reported annual income provided by the borrower during registration.
#
# annual_inc_joint	The combined self-reported annual income provided by the co-borrowers during registration
#
# application_type	Indicates whether the loan is an individual application or a joint application with two co-borrowers
#
# avg_cur_bal	Average current balance of all accounts
#
# bc_open_to_buy	Total open to buy on revolving bankcards
#
# bc_util	Ratio of total current balance to high credit/credit limit for all bankcard accounts
#
# chargeoff_within_12_mths	Number of charge-offs within 12 months
#
# collection_recovery_fee	post charge off collection fee
#
# collections_12_mths_ex_med	Number of collections in 12 months excluding medical collections
#
# debt_settlement_flag	Flags whether or not the borrower, who has charged-off, is working with a debt-settlement company
#
# debt_settlement_flag_date	The most recent date that the Debt_Settlement_Flag has been set
#
# deferral_term	Amount of months that the borrower is expected to pay less than the contractual monthly payment amount due to a hardship plan
#
# delinq_2yrs	The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years
#
# delinq_amnt	The past-due amount owed for the accounts on which the borrower is now delinquent
#
# desc	Loan description provided by the borrower
#
# disbursement_method	The method by which the borrower receives their loan. Possible values are: CASH, DIRECT_PAY
#
# dti	A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income
#
# dti_joint	A ratio calculated using the co-borrowers' total monthly payments on the total debt obligations, excluding mortgages and the requested LC loan, divided by the co-borrowers' combined self-reported monthly income
#
# earliest_cr_line	The month the borrower's earliest reported credit line was opened
#
# emp_length	Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years
#
# emp_title	The job title supplied by the Borrower when applying for the loan
#
# fico_range_high	The upper boundary range the borrower’s FICO at loan origination belongs to
#
# fico_range_low	The lower boundary range the borrower’s FICO at loan origination belongs to
#
# funded_amnt	The total amount committed to that loan at that point in time
#
# funded_amnt_inv	The total amount committed by investors for that loan at that point in time
#
# grade	LC assigned loan grade
#
# hardship_amount	The interest payment that the borrower has committed to make each month while they are on a hardship plan
#
# hardship_dpd	Account days past due as of the hardship plan start date
#
# hardship_end_date	The end date of the hardship plan period
#
# hardship_flag	Flags whether or not the borrower is on a hardship plan
#
# hardship_last_payment_amount	The last payment amount as of the hardship plan start date
#
# hardship_length	The number of months the borrower will make smaller payments than normally obligated due to a hardship plan
#
# hardship_loan_status	Loan Status as of the hardship plan start date
#
# hardship_payoff_balance_amount	The payoff balance amount as of the hardship plan start date
#
# hardship_reason	Describes the reason the hardship plan was offered
#
# hardship_start_date	The start date of the hardship plan period
#
# hardship_status	Describes if the hardship plan is active, pending, canceled, completed, or broken
#
# hardship_type	Describes the hardship plan offering
#
# home_ownership	The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER
#
# id	A unique LC assigned ID for the loan listing.
#
# il_util	Ratio of total current balance to high credit/credit limit on all install acct
#
# initial_list_status	The initial listing status of the loan. Possible values are – W, F
#
# inq_fi	Number of personal finance inquiries
#
# inq_last_12m	Number of credit inquiries in past 12 months
#
# inq_last_6mths	The number of inquiries in past 6 months (excluding auto and mortgage inquiries)
#
# installment	The monthly payment owed by the borrower if the loan originates.
#
# int_rate	Interest Rate on the loan
#
# issue_d	The month which the loan was funded
#
# last_credit_pull_d	The most recent month LC pulled credit for this loan
#
# last_fico_range_high	The upper boundary range the borrower’s last FICO pulled belongs to.
#
# last_fico_range_low	The lower boundary range the borrower’s last FICO pulled belongs to.
#
# last_pymnt_amnt	Last total payment amount received
#
# last_pymnt_d	Last month payment was received
#
# loan_amnt	The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
#
# loan_status	Current status of the loan
#
# max_bal_bc	Maximum current balance owed on all revolving accounts
#
# member_id	A unique LC assigned Id for the borrower member.
#
# mo_sin_old_il_acct	Months since oldest bank installment account opened
#
# mo_sin_old_rev_tl_op	Months since oldest revolving account opened
#
# mo_sin_rcnt_rev_tl_op	Months since most recent revolving account opened
#
# mo_sin_rcnt_tl	Months since most recent account opened
#
# mort_acc	Number of mortgage accounts.
#
# mths_since_last_delinq	The number of months since the borrower's last delinquency.
#
# mths_since_last_major_derog	Months since most recent 90-day or worse rating
#
# mths_since_last_record	The number of months since the last public record.
#
# mths_since_rcnt_il	Months since most recent installment accounts opened
#
# mths_since_recent_bc	Months since most recent bankcard account opened.
#
# mths_since_recent_bc_dlq	Months since most recent bankcard delinquency
#
# mths_since_recent_inq	Months since most recent inquiry.
#
# mths_since_recent_revol_delinq	Months since most recent revolving delinquency.
#
# next_pymnt_d	Next scheduled payment date
#
# num_accts_ever_120_pd	Number of accounts ever 120 or more days past due
#
# num_actv_bc_tl	Number of currently active bankcard accounts
#
# num_actv_rev_tl	Number of currently active revolving trades
#
# num_bc_sats	Number of satisfactory bankcard accounts
#
# num_bc_tl	Number of bankcard accounts
#
# num_il_tl	Number of installment accounts
#
# num_op_rev_tl	Number of open revolving accounts
#
# num_rev_accts	Number of revolving accounts
#
# num_rev_tl_bal_gt_0	Number of revolving trades with balance >0
#
# num_sats	Number of satisfactory accounts
#
# num_tl_120dpd_2m	Number of accounts currently 120 days past due (updated in past 2 months)
#
# num_tl_30dpd	Number of accounts currently 30 days past due (updated in past 2 months)
#
# num_tl_90g_dpd_24m	Number of accounts 90 or more days past due in last 24 months
#
# num_tl_op_past_12m	Number of accounts opened in past 12 months
#
# open_acc	The number of open credit lines in the borrower's credit file
#
# open_acc_6m	Number of open trades in last 6 months
#
# open_act_il	Number of currently active installment trades
#
# open_il_12m	Number of installment accounts opened in past 12 months
#
# open_il_24m	Number of installment accounts opened in past 24 months
#
# open_rv_12m	Number of revolving trades opened in past 12 months
#
# open_rv_24m	Number of revolving trades opened in past 24 months
#
# orig_projected_additional_accrued_interest	The original projected additional interest amount that will accrue for the given hardship payment plan as of the Hardship Start Date. This field will be null if the borrower has broken their hardship payment plan.
#
# out_prncp	Remaining outstanding principal for total amount funded
#
# out_prncp_inv	Remaining outstanding principal for portion of total amount funded by investors
#
# payment_plan_start_date	The day the first hardship plan payment is due. For example, if a borrower has a hardship plan period of 3 months, the start date is the start of the three-month period in which the borrower is allowed to make interest-only payments
#
# pct_tl_nvr_dlq	Percent of trades never delinquent
#
# percent_bc_gt_75	Percentage of all bankcard accounts > 75% of limit
#
# policy_code	"publicly available policy_code=1
#
# new products not publicly available policy_code=2"
#
# pub_rec	Number of derogatory public records
#
# pub_rec_bankruptcies	Number of public record bankruptcies
#
# purpose	A category provided by the borrower for the loan request
#
# pymnt_plan	Indicates if a payment plan has been put in place for the loan
#
# recoveries	post charge off gross recovery
#
# revol_bal	Total credit revolving balance
#
# revol_bal_joint 	 Sum of revolving credit balance of the co-borrowers, net of duplicate balances
#
# revol_util	Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit
#
# sec_app_chargeoff_within_12_mths 	 Number of charge-offs within last 12 months at time of application for the secondary applicant
#
# sec_app_collections_12_mths_ex_med 	 Number of collections within last 12 months excluding medical collections at time of application for the secondary applicant
#
# sec_app_earliest_cr_line 	 Earliest credit line at time of application for the secondary applicant
#
# sec_app_fico_range_high 	 FICO range (low) for the secondary applicant
#
# sec_app_fico_range_low 	 FICO range (high) for the secondary applicant
#
# sec_app_inq_last_6mths 	 Credit inquiries in the last 6 months at time of application for the secondary applicant
#
# sec_app_mort_acc 	 Number of mortgage accounts at time of application for the secondary applicant
#
# sec_app_mths_since_last_major_derog 	 Months since most recent 90-day or worse rating at time of application for the secondary applicant
#
# sec_app_num_rev_accts 	 Number of revolving accounts at time of application for the secondary applicant
#
# sec_app_open_acc 	 Number of open trades at time of application for the secondary applicant
#
# sec_app_open_act_il	 Number of currently active installment trades at time of application for the secondary applicant
#
# sec_app_revol_util 	 Ratio of total current balance to high credit/credit limit for all revolving accounts
#
# settlement_amount	The loan amount that the borrower has agreed to settle for
#
# settlement_date	The date that the borrower agrees to the settlement plan
#
# settlement_percentage	The settlement amount as a percentage of the payoff balance amount on the loan
#
# settlement_status	The status of the borrower’s settlement plan. Possible values are: COMPLETE, ACTIVE, BROKEN, CANCELLED, DENIED, DRAFT
#
# settlement_term	The number of months that the borrower will be on the settlement plan
#
# sub_grade	LC assigned loan subgrade
#
# tax_liens	Number of tax liens
#
# term	The number of payments on the loan. Values are in months and can be either 36 or 60
#
# title	The loan title provided by the borrower
#
# tot_coll_amt	Total collection amounts ever owed
#
# tot_cur_bal	Total current balance of all accounts
#
# tot_hi_cred_lim	Total high credit/credit limit
#
# total_acc	The total number of credit lines currently in the borrower's credit file
#
# total_bal_ex_mort	Total credit balance excluding mortgage
#
# total_bal_il	Total current balance of all installment accounts
#
# total_bc_limit	Total bankcard high credit/credit limit
#
# total_cu_tl	Number of finance trades
#
# total_il_high_credit_limit	Total installment high credit/credit limit
#
# total_pymnt	Payments received to date for total amount funded
#
# total_pymnt_inv	Payments received to date for portion of total amount funded by investors
#
# total_rec_int	Interest received to date
#
# total_rec_late_fee	Late fees received to date
#
# total_rec_prncp	Principal received to date
#
# total_rev_hi_lim  	Total revolving high credit/credit limit
#
# url	URL for the LC page with listing data
#
# verification_status	Indicates if income was verified by LC, not verified, or if the income source was verified
#
# verified_status_joint	Indicates if the co-borrowers' joint income was verified by LC, not verified, or if the income source was verified
#
# zip_code	The first 3 numbers of the zip code provided by the borrower in the loan application

# %% [markdown]
# ### Displaying data types.

# %%
df.dtypes
# Out:
# member_id                                     float64
# loan_amnt                                     float64
# funded_amnt                                   float64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                      float64
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# url                                            object
# desc                                           object
# purpose                                        object
# title                                          object
# zip_code                                       object
# addr_state                                     object
# dti                                           float64
# delinq_2yrs                                   float64
# earliest_cr_line                               object
# fico_range_low                                float64
# fico_range_high                               float64
# inq_last_6mths                                float64
# mths_since_last_delinq                        float64
# mths_since_last_record                        float64
# open_acc                                      float64
# pub_rec                                       float64
# revol_bal                                     float64
# revol_util                                    float64
# total_acc                                     float64
# initial_list_status                            object
# out_prncp                                     float64
# out_prncp_inv                                 float64
# total_pymnt                                   float64
# total_pymnt_inv                               float64
# total_rec_prncp                               float64
# total_rec_int                                 float64
# total_rec_late_fee                            float64
# recoveries                                    float64
# collection_recovery_fee                       float64
# last_pymnt_d                                   object
# last_pymnt_amnt                               float64
# next_pymnt_d                                  float64
# last_credit_pull_d                             object
# last_fico_range_high                          float64
# last_fico_range_low                           float64
# collections_12_mths_ex_med                    float64
# mths_since_last_major_derog                   float64
# policy_code                                   float64
# application_type                               object
# annual_inc_joint                              float64
# dti_joint                                     float64
# verification_status_joint                      object
# acc_now_delinq                                float64
# tot_coll_amt                                  float64
# tot_cur_bal                                   float64
# open_acc_6m                                   float64
# open_act_il                                   float64
# open_il_12m                                   float64
# open_il_24m                                   float64
# mths_since_rcnt_il                            float64
# total_bal_il                                  float64
# il_util                                       float64
# open_rv_12m                                   float64
# open_rv_24m                                   float64
# max_bal_bc                                    float64
# all_util                                      float64
# total_rev_hi_lim                              float64
# inq_fi                                        float64
# total_cu_tl                                   float64
# inq_last_12m                                  float64
# acc_open_past_24mths                          float64
# avg_cur_bal                                   float64
# bc_open_to_buy                                float64
# bc_util                                       float64
# chargeoff_within_12_mths                      float64
# delinq_amnt                                   float64
# mo_sin_old_il_acct                            float64
# mo_sin_old_rev_tl_op                          float64
# mo_sin_rcnt_rev_tl_op                         float64
# mo_sin_rcnt_tl                                float64
# mort_acc                                      float64
# mths_since_recent_bc                          float64
# mths_since_recent_bc_dlq                      float64
# mths_since_recent_inq                         float64
# mths_since_recent_revol_delinq                float64
# num_accts_ever_120_pd                         float64
# num_actv_bc_tl                                float64
# num_actv_rev_tl                               float64
# num_bc_sats                                   float64
# num_bc_tl                                     float64
# num_il_tl                                     float64
# num_op_rev_tl                                 float64
# num_rev_accts                                 float64
# num_rev_tl_bal_gt_0                           float64
# num_sats                                      float64
# num_tl_120dpd_2m                              float64
# num_tl_30dpd                                  float64
# num_tl_90g_dpd_24m                            float64
# num_tl_op_past_12m                            float64
# pct_tl_nvr_dlq                                float64
# percent_bc_gt_75                              float64
# pub_rec_bankruptcies                          float64
# tax_liens                                     float64
# tot_hi_cred_lim                               float64
# total_bal_ex_mort                             float64
# total_bc_limit                                float64
# total_il_high_credit_limit                    float64
# revol_bal_joint                               float64
# sec_app_fico_range_low                        float64
# sec_app_fico_range_high                       float64
# sec_app_earliest_cr_line                       object
# sec_app_inq_last_6mths                        float64
# sec_app_mort_acc                              float64
# sec_app_open_acc                              float64
# sec_app_revol_util                            float64
# sec_app_open_act_il                           float64
# sec_app_num_rev_accts                         float64
# sec_app_chargeoff_within_12_mths              float64
# sec_app_collections_12_mths_ex_med            float64
# sec_app_mths_since_last_major_derog           float64
# hardship_flag                                  object
# hardship_type                                  object
# hardship_reason                                object
# hardship_status                                object
# deferral_term                                 float64
# hardship_amount                               float64
# hardship_start_date                            object
# hardship_end_date                              object
# payment_plan_start_date                        object
# hardship_length                               float64
# hardship_dpd                                  float64
# hardship_loan_status                           object
# orig_projected_additional_accrued_interest    float64
# hardship_payoff_balance_amount                float64
# hardship_last_payment_amount                  float64
# disbursement_method                            object
# debt_settlement_flag                           object
# debt_settlement_flag_date                      object
# settlement_status                              object
# settlement_date                                object
# settlement_amount                             float64
# settlement_percentage                         float64
# settlement_term                               float64
# dtype: object

# %% [markdown]
# ### Counting null values in each column.

# %%
(100*df[df.columns[df.isnull().any()]].isnull().sum()/len(df.index)).sort_values()
# Out:
# zip_code                                        0.000074
# inq_last_6mths                                  0.000074
# tax_liens                                       0.002899
# last_credit_pull_d                              0.004088
# chargeoff_within_12_mths                        0.004163
# collections_12_mths_ex_med                      0.004163
# dti                                             0.027800
# pub_rec_bankruptcies                            0.051810
# revol_util                                      0.063703
# last_pymnt_d                                    0.171931
# title                                           1.238302
# total_bc_limit                                  3.514506
# mort_acc                                        3.514506
# acc_open_past_24mths                            3.514506
# total_bal_ex_mort                               3.514506
# num_sats                                        4.150791
# num_bc_sats                                     4.150791
# mths_since_recent_bc                            4.476366
# bc_open_to_buy                                  4.544900
# percent_bc_gt_75                                4.575525
# bc_util                                         4.602062
# tot_hi_cred_lim                                 5.019438
# mo_sin_rcnt_tl                                  5.019438
# num_accts_ever_120_pd                           5.019438
# num_tl_30dpd                                    5.019438
# total_il_high_credit_limit                      5.019438
# num_bc_tl                                       5.019438
# num_il_tl                                       5.019438
# num_op_rev_tl                                   5.019438
# num_rev_tl_bal_gt_0                             5.019438
# num_tl_op_past_12m                              5.019438
# num_tl_90g_dpd_24m                              5.019438
# num_actv_bc_tl                                  5.019438
# num_actv_rev_tl                                 5.019438
# tot_coll_amt                                    5.019438
# total_rev_hi_lim                                5.019438
# tot_cur_bal                                     5.019438
# num_rev_accts                                   5.019512
# mo_sin_rcnt_rev_tl_op                           5.019512
# mo_sin_old_rev_tl_op                            5.019512
# avg_cur_bal                                     5.021073
# pct_tl_nvr_dlq                                  5.030885
# emp_length                                      5.835904
# emp_title                                       6.376597
# mo_sin_old_il_acct                              7.847634
# num_tl_120dpd_2m                                8.726688
# mths_since_recent_inq                          12.939100
# mths_since_last_delinq                         50.452535
# open_rv_12m                                    60.039099
# open_rv_24m                                    60.039099
# total_bal_il                                   60.039099
# max_bal_bc                                     60.039099
# open_il_24m                                    60.039099
# open_il_12m                                    60.039099
# inq_fi                                         60.039099
# open_act_il                                    60.039099
# total_cu_tl                                    60.039173
# open_acc_6m                                    60.039173
# inq_last_12m                                   60.039173
# all_util                                       60.043038
# mths_since_rcnt_il                             61.095807
# il_util                                        65.434287
# mths_since_recent_revol_delinq                 66.553285
# mths_since_last_major_derog                    73.704945
# mths_since_recent_bc_dlq                       76.286506
# mths_since_last_record                         83.010979
# desc                                           90.817581
# settlement_status                              97.526518
# settlement_date                                97.526518
# settlement_amount                              97.526518
# debt_settlement_flag_date                      97.526518
# settlement_term                                97.526518
# settlement_percentage                          97.526518
# annual_inc_joint                               98.082226
# dti_joint                                      98.082449
# verification_status_joint                      98.097465
# sec_app_chargeoff_within_12_mths               98.615189
# sec_app_fico_range_low                         98.615189
# sec_app_fico_range_high                        98.615189
# sec_app_earliest_cr_line                       98.615189
# sec_app_inq_last_6mths                         98.615189
# sec_app_mort_acc                               98.615189
# sec_app_open_acc                               98.615189
# sec_app_open_act_il                            98.615189
# sec_app_num_rev_accts                          98.615189
# sec_app_collections_12_mths_ex_med             98.615189
# revol_bal_joint                                98.615263
# sec_app_revol_util                             98.639570
# sec_app_mths_since_last_major_derog            99.506062
# hardship_loan_status                           99.572292
# hardship_last_payment_amount                   99.572292
# hardship_payoff_balance_amount                 99.572292
# hardship_dpd                                   99.572292
# deferral_term                                  99.572292
# payment_plan_start_date                        99.572292
# hardship_end_date                              99.572292
# hardship_start_date                            99.572292
# hardship_amount                                99.572292
# hardship_status                                99.572292
# hardship_reason                                99.572292
# hardship_type                                  99.572292
# hardship_length                                99.572292
# orig_projected_additional_accrued_interest     99.720585
# next_pymnt_d                                  100.000000
# member_id                                     100.000000
# dtype: float64

# %%
df.describe(include='all').T
# Out:
#                                                   count   unique  \
# member_id                                             0      NaN
# loan_amnt                                   1.34531e+06      NaN
# funded_amnt                                 1.34531e+06      NaN
# funded_amnt_inv                             1.34531e+06      NaN
# term                                            1345310        2
# int_rate                                    1.34531e+06      NaN
# installment                                 1.34531e+06      NaN
# grade                                           1345310        7
# sub_grade                                       1345310       35
# emp_title                                       1259525   378353
# emp_length                                      1266799       11
# home_ownership                                  1345310        6
# annual_inc                                  1.34531e+06      NaN
# verification_status                             1345310        3
# issue_d                                         1345310      139
# loan_status                                     1345310        2
# pymnt_plan                                      1345310        1
# url                                             1345310  1345310
# desc                                             123532   122005
# purpose                                         1345310       14
# title                                           1328651    61682
# zip_code                                        1345309      943
# addr_state                                      1345310       51
# dti                                         1.34494e+06      NaN
# delinq_2yrs                                 1.34531e+06      NaN
# earliest_cr_line                                1345310      739
# fico_range_low                              1.34531e+06      NaN
# fico_range_high                             1.34531e+06      NaN
# inq_last_6mths                              1.34531e+06      NaN
# mths_since_last_delinq                           666567      NaN
# mths_since_last_record                           228555      NaN
# open_acc                                    1.34531e+06      NaN
# pub_rec                                     1.34531e+06      NaN
# revol_bal                                   1.34531e+06      NaN
# revol_util                                  1.34445e+06      NaN
# total_acc                                   1.34531e+06      NaN
# initial_list_status                             1345310        2
# out_prncp                                   1.34531e+06      NaN
# out_prncp_inv                               1.34531e+06      NaN
# total_pymnt                                 1.34531e+06      NaN
# total_pymnt_inv                             1.34531e+06      NaN
# total_rec_prncp                             1.34531e+06      NaN
# total_rec_int                               1.34531e+06      NaN
# total_rec_late_fee                          1.34531e+06      NaN
# recoveries                                  1.34531e+06      NaN
# collection_recovery_fee                     1.34531e+06      NaN
# last_pymnt_d                                    1342997      135
# last_pymnt_amnt                             1.34531e+06      NaN
# next_pymnt_d                                          0      NaN
# last_credit_pull_d                              1345255      140
# last_fico_range_high                        1.34531e+06      NaN
# last_fico_range_low                         1.34531e+06      NaN
# collections_12_mths_ex_med                  1.34525e+06      NaN
# mths_since_last_major_derog                      353750      NaN
# policy_code                                 1.34531e+06      NaN
# application_type                                1345310        2
# annual_inc_joint                                  25800      NaN
# dti_joint                                         25797      NaN
# verification_status_joint                         25595        3
# acc_now_delinq                              1.34531e+06      NaN
# tot_coll_amt                                1.27778e+06      NaN
# tot_cur_bal                                 1.27778e+06      NaN
# open_acc_6m                                      537597      NaN
# open_act_il                                      537598      NaN
# open_il_12m                                      537598      NaN
# open_il_24m                                      537598      NaN
# mths_since_rcnt_il                               523382      NaN
# total_bal_il                                     537598      NaN
# il_util                                          465016      NaN
# open_rv_12m                                      537598      NaN
# open_rv_24m                                      537598      NaN
# max_bal_bc                                       537598      NaN
# all_util                                         537545      NaN
# total_rev_hi_lim                            1.27778e+06      NaN
# inq_fi                                           537598      NaN
# total_cu_tl                                      537597      NaN
# inq_last_12m                                     537597      NaN
# acc_open_past_24mths                        1.29803e+06      NaN
# avg_cur_bal                                 1.27776e+06      NaN
# bc_open_to_buy                              1.28417e+06      NaN
# bc_util                                      1.2834e+06      NaN
# chargeoff_within_12_mths                    1.34525e+06      NaN
# delinq_amnt                                 1.34531e+06      NaN
# mo_sin_old_il_acct                          1.23974e+06      NaN
# mo_sin_old_rev_tl_op                        1.27778e+06      NaN
# mo_sin_rcnt_rev_tl_op                       1.27778e+06      NaN
# mo_sin_rcnt_tl                              1.27778e+06      NaN
# mort_acc                                    1.29803e+06      NaN
# mths_since_recent_bc                        1.28509e+06      NaN
# mths_since_recent_bc_dlq                         319020      NaN
# mths_since_recent_inq                       1.17124e+06      NaN
# mths_since_recent_revol_delinq                   449962      NaN
# num_accts_ever_120_pd                       1.27778e+06      NaN
# num_actv_bc_tl                              1.27778e+06      NaN
# num_actv_rev_tl                             1.27778e+06      NaN
# num_bc_sats                                 1.28947e+06      NaN
# num_bc_tl                                   1.27778e+06      NaN
# num_il_tl                                   1.27778e+06      NaN
# num_op_rev_tl                               1.27778e+06      NaN
# num_rev_accts                               1.27778e+06      NaN
# num_rev_tl_bal_gt_0                         1.27778e+06      NaN
# num_sats                                    1.28947e+06      NaN
# num_tl_120dpd_2m                            1.22791e+06      NaN
# num_tl_30dpd                                1.27778e+06      NaN
# num_tl_90g_dpd_24m                          1.27778e+06      NaN
# num_tl_op_past_12m                          1.27778e+06      NaN
# pct_tl_nvr_dlq                              1.27763e+06      NaN
# percent_bc_gt_75                            1.28376e+06      NaN
# pub_rec_bankruptcies                        1.34461e+06      NaN
# tax_liens                                   1.34527e+06      NaN
# tot_hi_cred_lim                             1.27778e+06      NaN
# total_bal_ex_mort                           1.29803e+06      NaN
# total_bc_limit                              1.29803e+06      NaN
# total_il_high_credit_limit                  1.27778e+06      NaN
# revol_bal_joint                                   18629      NaN
# sec_app_fico_range_low                            18630      NaN
# sec_app_fico_range_high                           18630      NaN
# sec_app_earliest_cr_line                          18630      570
# sec_app_inq_last_6mths                            18630      NaN
# sec_app_mort_acc                                  18630      NaN
# sec_app_open_acc                                  18630      NaN
# sec_app_revol_util                                18302      NaN
# sec_app_open_act_il                               18630      NaN
# sec_app_num_rev_accts                             18630      NaN
# sec_app_chargeoff_within_12_mths                  18630      NaN
# sec_app_collections_12_mths_ex_med                18630      NaN
# sec_app_mths_since_last_major_derog                6645      NaN
# hardship_flag                                   1345310        1
# hardship_type                                      5754        1
# hardship_reason                                    5754        9
# hardship_status                                    5754        2
# deferral_term                                      5754      NaN
# hardship_amount                                    5754      NaN
# hardship_start_date                                5754       26
# hardship_end_date                                  5754       25
# payment_plan_start_date                            5754       25
# hardship_length                                    5754      NaN
# hardship_dpd                                       5754      NaN
# hardship_loan_status                               5754        5
# orig_projected_additional_accrued_interest         3759      NaN
# hardship_payoff_balance_amount                     5754      NaN
# hardship_last_payment_amount                       5754      NaN
# disbursement_method                             1345310        2
# debt_settlement_flag                            1345310        2
# debt_settlement_flag_date                         33276       83
# settlement_status                                 33276        3
# settlement_date                                   33276       89
# settlement_amount                                 33276      NaN
# settlement_percentage                             33276      NaN
# settlement_term                                   33276      NaN
#
#                                                                                                           top  \
# member_id                                                                                                 NaN
# loan_amnt                                                                                                 NaN
# funded_amnt                                                                                               NaN
# funded_amnt_inv                                                                                           NaN
# term                                                                                                36 months
# int_rate                                                                                                  NaN
# installment                                                                                               NaN
# grade                                                                                                       B
# sub_grade                                                                                                  C1
# emp_title                                                                                             Teacher
# emp_length                                                                                          10+ years
# home_ownership                                                                                       MORTGAGE
# annual_inc                                                                                                NaN
# verification_status                                                                           Source Verified
# issue_d                                                                                              Mar-2016
# loan_status                                                                                        Fully Paid
# pymnt_plan                                                                                                  n
# url                                         https://lendingclub.com/browse/loanDetail.action?loan_id=12527162
# desc
# purpose                                                                                    debt_consolidation
# title                                                                                      Debt consolidation
# zip_code                                                                                                945xx
# addr_state                                                                                                 CA
# dti                                                                                                       NaN
# delinq_2yrs                                                                                               NaN
# earliest_cr_line                                                                                     Aug-2001
# fico_range_low                                                                                            NaN
# fico_range_high                                                                                           NaN
# inq_last_6mths                                                                                            NaN
# mths_since_last_delinq                                                                                    NaN
# mths_since_last_record                                                                                    NaN
# open_acc                                                                                                  NaN
# pub_rec                                                                                                   NaN
# revol_bal                                                                                                 NaN
# revol_util                                                                                                NaN
# total_acc                                                                                                 NaN
# initial_list_status                                                                                         w
# out_prncp                                                                                                 NaN
# out_prncp_inv                                                                                             NaN
# total_pymnt                                                                                               NaN
# total_pymnt_inv                                                                                           NaN
# total_rec_prncp                                                                                           NaN
# total_rec_int                                                                                             NaN
# total_rec_late_fee                                                                                        NaN
# recoveries                                                                                                NaN
# collection_recovery_fee                                                                                   NaN
# last_pymnt_d                                                                                         Aug-2018
# last_pymnt_amnt                                                                                           NaN
# next_pymnt_d                                                                                              NaN
# last_credit_pull_d                                                                                   Mar-2019
# last_fico_range_high                                                                                      NaN
# last_fico_range_low                                                                                       NaN
# collections_12_mths_ex_med                                                                                NaN
# mths_since_last_major_derog                                                                               NaN
# policy_code                                                                                               NaN
# application_type                                                                                   Individual
# annual_inc_joint                                                                                          NaN
# dti_joint                                                                                                 NaN
# verification_status_joint                                                                        Not Verified
# acc_now_delinq                                                                                            NaN
# tot_coll_amt                                                                                              NaN
# tot_cur_bal                                                                                               NaN
# open_acc_6m                                                                                               NaN
# open_act_il                                                                                               NaN
# open_il_12m                                                                                               NaN
# open_il_24m                                                                                               NaN
# mths_since_rcnt_il                                                                                        NaN
# total_bal_il                                                                                              NaN
# il_util                                                                                                   NaN
# open_rv_12m                                                                                               NaN
# open_rv_24m                                                                                               NaN
# max_bal_bc                                                                                                NaN
# all_util                                                                                                  NaN
# total_rev_hi_lim                                                                                          NaN
# inq_fi                                                                                                    NaN
# total_cu_tl                                                                                               NaN
# inq_last_12m                                                                                              NaN
# acc_open_past_24mths                                                                                      NaN
# avg_cur_bal                                                                                               NaN
# bc_open_to_buy                                                                                            NaN
# bc_util                                                                                                   NaN
# chargeoff_within_12_mths                                                                                  NaN
# delinq_amnt                                                                                               NaN
# mo_sin_old_il_acct                                                                                        NaN
# mo_sin_old_rev_tl_op                                                                                      NaN
# mo_sin_rcnt_rev_tl_op                                                                                     NaN
# mo_sin_rcnt_tl                                                                                            NaN
# mort_acc                                                                                                  NaN
# mths_since_recent_bc                                                                                      NaN
# mths_since_recent_bc_dlq                                                                                  NaN
# mths_since_recent_inq                                                                                     NaN
# mths_since_recent_revol_delinq                                                                            NaN
# num_accts_ever_120_pd                                                                                     NaN
# num_actv_bc_tl                                                                                            NaN
# num_actv_rev_tl                                                                                           NaN
# num_bc_sats                                                                                               NaN
# num_bc_tl                                                                                                 NaN
# num_il_tl                                                                                                 NaN
# num_op_rev_tl                                                                                             NaN
# num_rev_accts                                                                                             NaN
# num_rev_tl_bal_gt_0                                                                                       NaN
# num_sats                                                                                                  NaN
# num_tl_120dpd_2m                                                                                          NaN
# num_tl_30dpd                                                                                              NaN
# num_tl_90g_dpd_24m                                                                                        NaN
# num_tl_op_past_12m                                                                                        NaN
# pct_tl_nvr_dlq                                                                                            NaN
# percent_bc_gt_75                                                                                          NaN
# pub_rec_bankruptcies                                                                                      NaN
# tax_liens                                                                                                 NaN
# tot_hi_cred_lim                                                                                           NaN
# total_bal_ex_mort                                                                                         NaN
# total_bc_limit                                                                                            NaN
# total_il_high_credit_limit                                                                                NaN
# revol_bal_joint                                                                                           NaN
# sec_app_fico_range_low                                                                                    NaN
# sec_app_fico_range_high                                                                                   NaN
# sec_app_earliest_cr_line                                                                             Aug-2006
# sec_app_inq_last_6mths                                                                                    NaN
# sec_app_mort_acc                                                                                          NaN
# sec_app_open_acc                                                                                          NaN
# sec_app_revol_util                                                                                        NaN
# sec_app_open_act_il                                                                                       NaN
# sec_app_num_rev_accts                                                                                     NaN
# sec_app_chargeoff_within_12_mths                                                                          NaN
# sec_app_collections_12_mths_ex_med                                                                        NaN
# sec_app_mths_since_last_major_derog                                                                       NaN
# hardship_flag                                                                                               N
# hardship_type                                                                 INTEREST ONLY-3 MONTHS DEFERRAL
# hardship_reason                                                                              NATURAL_DISASTER
# hardship_status                                                                                     COMPLETED
# deferral_term                                                                                             NaN
# hardship_amount                                                                                           NaN
# hardship_start_date                                                                                  Sep-2017
# hardship_end_date                                                                                    Dec-2017
# payment_plan_start_date                                                                              Oct-2017
# hardship_length                                                                                           NaN
# hardship_dpd                                                                                              NaN
# hardship_loan_status                                                                        Late (16-30 days)
# orig_projected_additional_accrued_interest                                                                NaN
# hardship_payoff_balance_amount                                                                            NaN
# hardship_last_payment_amount                                                                              NaN
# disbursement_method                                                                                      Cash
# debt_settlement_flag                                                                                        N
# debt_settlement_flag_date                                                                            Jan-2019
# settlement_status                                                                                    COMPLETE
# settlement_date                                                                                      Jan-2019
# settlement_amount                                                                                         NaN
# settlement_percentage                                                                                     NaN
# settlement_term                                                                                           NaN
#
#                                                freq         mean        std  \
# member_id                                       NaN          NaN        NaN
# loan_amnt                                       NaN        14420    8717.05
# funded_amnt                                     NaN      14411.6    8713.12
# funded_amnt_inv                                 NaN      14389.1    8715.49
# term                                        1020743          NaN        NaN
# int_rate                                        NaN      13.2396    4.76872
# installment                                     NaN      438.076    261.513
# grade                                        392741          NaN        NaN
# sub_grade                                     85494          NaN        NaN
# emp_title                                     21268          NaN        NaN
# emp_length                                   442199          NaN        NaN
# home_ownership                               665579          NaN        NaN
# annual_inc                                      NaN      76247.6    69925.1
# verification_status                          521273          NaN        NaN
# issue_d                                       48937          NaN        NaN
# loan_status                                 1076751          NaN        NaN
# pymnt_plan                                  1345310          NaN        NaN
# url                                               1          NaN        NaN
# desc                                            236          NaN        NaN
# purpose                                      780321          NaN        NaN
# title                                        660960          NaN        NaN
# zip_code                                      15005          NaN        NaN
# addr_state                                   196528          NaN        NaN
# dti                                             NaN      18.2827    11.1604
# delinq_2yrs                                     NaN     0.317794   0.877992
# earliest_cr_line                               9391          NaN        NaN
# fico_range_low                                  NaN      696.185    31.8525
# fico_range_high                                 NaN      700.185    31.8532
# inq_last_6mths                                  NaN     0.655081   0.937774
# mths_since_last_delinq                          NaN      34.3121    21.9192
# mths_since_last_record                          NaN      70.6371    26.5792
# open_acc                                        NaN      11.5935    5.47379
# pub_rec                                         NaN     0.215276   0.601865
# revol_bal                                       NaN      16248.1    22328.2
# revol_util                                      NaN        51.81    24.5211
# total_acc                                       NaN      24.9808    11.9985
# initial_list_status                          784010          NaN        NaN
# out_prncp                                       NaN            0          0
# out_prncp_inv                                   NaN            0          0
# total_pymnt                                     NaN      14823.9    10351.5
# total_pymnt_inv                                 NaN      14800.2    10349.8
# total_rec_prncp                                 NaN      12181.9    8867.78
# total_rec_int                                   NaN      2398.95    2600.95
# total_rec_late_fee                              NaN      1.58298    10.7637
# recoveries                                      NaN      241.439    956.528
# collection_recovery_fee                         NaN      40.2299    167.745
# last_pymnt_d                                  39615          NaN        NaN
# last_pymnt_amnt                                 NaN      5423.57       7118
# next_pymnt_d                                    NaN          NaN        NaN
# last_credit_pull_d                           470827          NaN        NaN
# last_fico_range_high                            NaN      677.286    81.3935
# last_fico_range_low                             NaN      660.163    132.769
# collections_12_mths_ex_med                      NaN    0.0171336   0.146915
# mths_since_last_major_derog                     NaN      43.7012    21.3785
# policy_code                                     NaN            1          0
# application_type                            1319510          NaN        NaN
# annual_inc_joint                                NaN       117383    59783.8
# dti_joint                                       NaN      18.8966    7.72291
# verification_status_joint                     14872          NaN        NaN
# acc_now_delinq                                  NaN   0.00504568  0.0771611
# tot_coll_amt                                    NaN      249.386      11065
# tot_cur_bal                                     NaN       141134     157548
# open_acc_6m                                     NaN      1.05056    1.20884
# open_act_il                                     NaN      2.79256    2.98992
# open_il_12m                                     NaN     0.776366   0.993202
# open_il_24m                                     NaN      1.74275    1.68572
# mths_since_rcnt_il                              NaN       19.593    24.8717
# total_bal_il                                    NaN        35862    42906.6
# il_util                                         NaN      71.4221    22.9092
# open_rv_12m                                     NaN      1.42089    1.57485
# open_rv_24m                                     NaN      3.00507    2.70147
# max_bal_bc                                      NaN       5537.7    5471.95
# all_util                                        NaN      58.1764    20.9354
# total_rev_hi_lim                                NaN      32790.9    36642.6
# inq_fi                                          NaN      1.09331    1.58626
# total_cu_tl                                     NaN      1.60924    2.82507
# inq_last_12m                                    NaN      2.31238    2.54207
# acc_open_past_24mths                            NaN      4.69287    3.18681
# avg_cur_bal                                     NaN      13488.6    16289.7
# bc_open_to_buy                                  NaN      10186.2    15350.8
# bc_util                                         NaN      59.9396    28.2932
# chargeoff_within_12_mths                        NaN   0.00906223   0.109719
# delinq_amnt                                     NaN      14.8955    809.525
# mo_sin_old_il_acct                              NaN      125.798    52.2334
# mo_sin_old_rev_tl_op                            NaN      181.476    94.5051
# mo_sin_rcnt_rev_tl_op                           NaN      13.1157    16.3411
# mo_sin_rcnt_tl                                  NaN      7.85475    8.72898
# mort_acc                                        NaN      1.67078    2.00044
# mths_since_recent_bc                            NaN      23.8177    30.7331
# mths_since_recent_bc_dlq                        NaN      39.6526    22.6982
# mths_since_recent_inq                           NaN      6.71321    5.84995
# mths_since_recent_revol_delinq                  NaN      35.8047    22.4282
# num_accts_ever_120_pd                           NaN     0.509574    1.32559
# num_actv_bc_tl                                  NaN      3.64273    2.24824
# num_actv_rev_tl                                 NaN      5.64348    3.30179
# num_bc_sats                                     NaN      4.73422     2.9524
# num_bc_tl                                       NaN       8.1011    4.80089
# num_il_tl                                       NaN      8.56789    7.38654
# num_op_rev_tl                                   NaN      8.27885    4.55797
# num_rev_accts                                   NaN      14.6103    8.11931
# num_rev_tl_bal_gt_0                             NaN      5.59266    3.21527
# num_sats                                        NaN      11.6391    5.48249
# num_tl_120dpd_2m                                NaN  0.000820093  0.0304988
# num_tl_30dpd                                    NaN   0.00341842  0.0623479
# num_tl_90g_dpd_24m                              NaN    0.0888836   0.504085
# num_tl_op_past_12m                              NaN      2.17889    1.84504
# pct_tl_nvr_dlq                                  NaN      94.1647    8.74412
# percent_bc_gt_75                                NaN       45.156    36.0072
# pub_rec_bankruptcies                            NaN     0.134444   0.377929
# tax_liens                                       NaN      0.05213   0.397911
# tot_hi_cred_lim                                 NaN       174388     178096
# total_bal_ex_mort                               NaN      49666.4    47743.6
# total_bc_limit                                  NaN        21634    21554.8
# total_il_high_credit_limit                      NaN      42133.2    43252.1
# revol_bal_joint                                 NaN      31557.6    26885.4
# sec_app_fico_range_low                          NaN       665.97    45.8732
# sec_app_fico_range_high                         NaN       669.97    45.8732
# sec_app_earliest_cr_line                        198          NaN        NaN
# sec_app_inq_last_6mths                          NaN     0.752013    1.09175
# sec_app_mort_acc                                NaN       1.6701    1.83921
# sec_app_open_acc                                NaN      11.3054    6.50378
# sec_app_revol_util                              NaN      57.1959    26.4789
# sec_app_open_act_il                             NaN      2.94536    3.19459
# sec_app_num_rev_accts                           NaN      12.8002    8.33952
# sec_app_chargeoff_within_12_mths                NaN    0.0566828   0.462691
# sec_app_collections_12_mths_ex_med              NaN    0.0873323   0.429776
# sec_app_mths_since_last_major_derog             NaN       36.357    23.9852
# hardship_flag                               1345310          NaN        NaN
# hardship_type                                  5754          NaN        NaN
# hardship_reason                                1619          NaN        NaN
# hardship_status                                3759          NaN        NaN
# deferral_term                                   NaN            3          0
# hardship_amount                                 NaN      147.434    128.469
# hardship_start_date                            1493          NaN        NaN
# hardship_end_date                              1108          NaN        NaN
# payment_plan_start_date                        1065          NaN        NaN
# hardship_length                                 NaN            3          0
# hardship_dpd                                    NaN      13.9494    9.77741
# hardship_loan_status                           2596          NaN        NaN
# orig_projected_additional_accrued_interest      NaN      410.697    357.512
# hardship_payoff_balance_amount                  NaN      10995.1    7474.26
# hardship_last_payment_amount                    NaN      184.689     196.46
# disbursement_method                         1338410          NaN        NaN
# debt_settlement_flag                        1312034          NaN        NaN
# debt_settlement_flag_date                      2451          NaN        NaN
# settlement_status                             14497          NaN        NaN
# settlement_date                                1635          NaN        NaN
# settlement_amount                               NaN      5029.93    3684.83
# settlement_percentage                           NaN      47.6917    7.30611
# settlement_term                                 NaN      13.1581    8.23559
#
#                                                 min      25%      50%  \
# member_id                                       NaN      NaN      NaN
# loan_amnt                                       500     8000    12000
# funded_amnt                                     500     8000    12000
# funded_amnt_inv                                   0     7875    12000
# term                                            NaN      NaN      NaN
# int_rate                                       5.31     9.75    12.74
# installment                                    4.93   248.48   375.43
# grade                                           NaN      NaN      NaN
# sub_grade                                       NaN      NaN      NaN
# emp_title                                       NaN      NaN      NaN
# emp_length                                      NaN      NaN      NaN
# home_ownership                                  NaN      NaN      NaN
# annual_inc                                        0    45780    65000
# verification_status                             NaN      NaN      NaN
# issue_d                                         NaN      NaN      NaN
# loan_status                                     NaN      NaN      NaN
# pymnt_plan                                      NaN      NaN      NaN
# url                                             NaN      NaN      NaN
# desc                                            NaN      NaN      NaN
# purpose                                         NaN      NaN      NaN
# title                                           NaN      NaN      NaN
# zip_code                                        NaN      NaN      NaN
# addr_state                                      NaN      NaN      NaN
# dti                                              -1    11.79    17.61
# delinq_2yrs                                       0        0        0
# earliest_cr_line                                NaN      NaN      NaN
# fico_range_low                                  625      670      690
# fico_range_high                                 629      674      694
# inq_last_6mths                                    0        0        0
# mths_since_last_delinq                            0       16       31
# mths_since_last_record                            0       53       72
# open_acc                                          0        8       11
# pub_rec                                           0        0        0
# revol_bal                                         0     5943    11134
# revol_util                                        0     33.4     52.2
# total_acc                                         2       16       23
# initial_list_status                             NaN      NaN      NaN
# out_prncp                                         0        0        0
# out_prncp_inv                                     0        0        0
# total_pymnt                                       0  6838.04    12128
# total_pymnt_inv                                   0  6816.51  12107.3
# total_rec_prncp                                   0     5000    10000
# total_rec_int                                     0   766.96  1569.77
# total_rec_late_fee                         -5.1e-09        0        0
# recoveries                                        0        0        0
# collection_recovery_fee                           0        0        0
# last_pymnt_d                                    NaN      NaN      NaN
# last_pymnt_amnt                                   0   398.52  2042.05
# next_pymnt_d                                    NaN      NaN      NaN
# last_credit_pull_d                              NaN      NaN      NaN
# last_fico_range_high                              0      629      694
# last_fico_range_low                               0      625      690
# collections_12_mths_ex_med                        0        0        0
# mths_since_last_major_derog                       0       27       44
# policy_code                                       1        1        1
# application_type                                NaN      NaN      NaN
# annual_inc_joint                              11000    80000   106300
# dti_joint                                         0    13.29    18.46
# verification_status_joint                       NaN      NaN      NaN
# acc_now_delinq                                    0        0        0
# tot_coll_amt                                      0        0        0
# tot_cur_bal                                       0    29423    80231
# open_acc_6m                                       0        0        1
# open_act_il                                       0        1        2
# open_il_12m                                       0        0        1
# open_il_24m                                       0        1        1
# mths_since_rcnt_il                                0        6       12
# total_bal_il                                      0     9605    24062
# il_util                                           0       58       75
# open_rv_12m                                       0        0        1
# open_rv_24m                                       0        1        2
# max_bal_bc                                        0     2180     4201
# all_util                                          0       44       59
# total_rev_hi_lim                                  0    14000    24100
# inq_fi                                            0        0        1
# total_cu_tl                                       0        0        0
# inq_last_12m                                      0        1        2
# acc_open_past_24mths                              0        2        4
# avg_cur_bal                                       0     3101     7407
# bc_open_to_buy                                    0     1464     4700
# bc_util                                           0     38.3     63.2
# chargeoff_within_12_mths                          0        0        0
# delinq_amnt                                       0        0        0
# mo_sin_old_il_acct                                0       98      129
# mo_sin_old_rev_tl_op                              2      117      164
# mo_sin_rcnt_rev_tl_op                             0        4        8
# mo_sin_rcnt_tl                                    0        3        5
# mort_acc                                          0        0        1
# mths_since_recent_bc                              0        6       13
# mths_since_recent_bc_dlq                          0       21       38
# mths_since_recent_inq                             0        2        5
# mths_since_recent_revol_delinq                    0       17       33
# num_accts_ever_120_pd                             0        0        0
# num_actv_bc_tl                                    0        2        3
# num_actv_rev_tl                                   0        3        5
# num_bc_sats                                       0        3        4
# num_bc_tl                                         0        5        7
# num_il_tl                                         0        4        7
# num_op_rev_tl                                     0        5        7
# num_rev_accts                                     0        9       13
# num_rev_tl_bal_gt_0                               0        3        5
# num_sats                                          0        8       11
# num_tl_120dpd_2m                                  0        0        0
# num_tl_30dpd                                      0        0        0
# num_tl_90g_dpd_24m                                0        0        0
# num_tl_op_past_12m                                0        1        2
# pct_tl_nvr_dlq                                    0     91.3       98
# percent_bc_gt_75                                  0       10     42.9
# pub_rec_bankruptcies                              0        0        0
# tax_liens                                         0        0        0
# tot_hi_cred_lim                                   0  49620.5   112373
# total_bal_ex_mort                                 0    20886    37296
# total_bc_limit                                    0     7800    15100
# total_il_high_credit_limit                        0    14738    31681
# revol_bal_joint                                   0    13837    24659
# sec_app_fico_range_low                          540      640      665
# sec_app_fico_range_high                         544      644      669
# sec_app_earliest_cr_line                        NaN      NaN      NaN
# sec_app_inq_last_6mths                            0        0        0
# sec_app_mort_acc                                  0        0        1
# sec_app_open_acc                                  0        7       10
# sec_app_revol_util                                0     37.9     59.3
# sec_app_open_act_il                               0        1        2
# sec_app_num_rev_accts                             0        7       11
# sec_app_chargeoff_within_12_mths                  0        0        0
# sec_app_collections_12_mths_ex_med                0        0        0
# sec_app_mths_since_last_major_derog               0       15       35
# hardship_flag                                   NaN      NaN      NaN
# hardship_type                                   NaN      NaN      NaN
# hardship_reason                                 NaN      NaN      NaN
# hardship_status                                 NaN      NaN      NaN
# deferral_term                                     3        3        3
# hardship_amount                                0.64  53.2675   109.82
# hardship_start_date                             NaN      NaN      NaN
# hardship_end_date                               NaN      NaN      NaN
# payment_plan_start_date                         NaN      NaN      NaN
# hardship_length                                   3        3        3
# hardship_dpd                                      0        5       15
# hardship_loan_status                            NaN      NaN      NaN
# orig_projected_additional_accrued_interest     1.92   147.45   303.45
# hardship_payoff_balance_amount                55.73  5037.31   9305.1
# hardship_last_payment_amount                   0.01    39.57   120.97
# disbursement_method                             NaN      NaN      NaN
# debt_settlement_flag                            NaN      NaN      NaN
# debt_settlement_flag_date                       NaN      NaN      NaN
# settlement_status                               NaN      NaN      NaN
# settlement_date                                 NaN      NaN      NaN
# settlement_amount                             44.21  2228.62  4174.68
# settlement_percentage                           0.2       45       45
# settlement_term                                   0        6       14
#
#                                                 75%          max
# member_id                                       NaN          NaN
# loan_amnt                                     20000        40000
# funded_amnt                                   20000        40000
# funded_amnt_inv                               20000        40000
# term                                            NaN          NaN
# int_rate                                      15.99        30.99
# installment                                  580.73      1719.83
# grade                                           NaN          NaN
# sub_grade                                       NaN          NaN
# emp_title                                       NaN          NaN
# emp_length                                      NaN          NaN
# home_ownership                                  NaN          NaN
# annual_inc                                    90000  1.09992e+07
# verification_status                             NaN          NaN
# issue_d                                         NaN          NaN
# loan_status                                     NaN          NaN
# pymnt_plan                                      NaN          NaN
# url                                             NaN          NaN
# desc                                            NaN          NaN
# purpose                                         NaN          NaN
# title                                           NaN          NaN
# zip_code                                        NaN          NaN
# addr_state                                      NaN          NaN
# dti                                           24.06          999
# delinq_2yrs                                       0           39
# earliest_cr_line                                NaN          NaN
# fico_range_low                                  710          845
# fico_range_high                                 714          850
# inq_last_6mths                                    1            8
# mths_since_last_delinq                           50          226
# mths_since_last_record                           90          129
# open_acc                                         14           90
# pub_rec                                           0           86
# revol_bal                                   19755.8  2.90484e+06
# revol_util                                     70.7        892.3
# total_acc                                        32          176
# initial_list_status                             NaN          NaN
# out_prncp                                         0            0
# out_prncp_inv                                     0            0
# total_pymnt                                 20585.6      63296.9
# total_pymnt_inv                               20559      63296.9
# total_rec_prncp                               17275        40000
# total_rec_int                               3031.37      28192.5
# total_rec_late_fee                                0      1188.83
# recoveries                                        0      39859.6
# collection_recovery_fee                           0      7174.72
# last_pymnt_d                                    NaN          NaN
# last_pymnt_amnt                             8250.57      42192.1
# next_pymnt_d                                    NaN          NaN
# last_credit_pull_d                              NaN          NaN
# last_fico_range_high                            734          850
# last_fico_range_low                             730          845
# collections_12_mths_ex_med                        0           20
# mths_since_last_major_derog                      61          226
# policy_code                                       1            1
# application_type                                NaN          NaN
# annual_inc_joint                             140000    1.837e+06
# dti_joint                                     24.18        69.49
# verification_status_joint                       NaN          NaN
# acc_now_delinq                                    0           14
# tot_coll_amt                                      0  9.15254e+06
# tot_cur_bal                                  210715  8.00008e+06
# open_acc_6m                                       2           18
# open_act_il                                       3           57
# open_il_12m                                       1           25
# open_il_24m                                       2           51
# mths_since_rcnt_il                               22          511
# total_bal_il                                46724.8  1.71101e+06
# il_util                                          87          558
# open_rv_12m                                       2           28
# open_rv_24m                                       4           53
# max_bal_bc                                  7198.75       776843
# all_util                                         73          198
# total_rev_hi_lim                              40600        1e+07
# inq_fi                                            2           48
# total_cu_tl                                       2           79
# inq_last_12m                                      3           67
# acc_open_past_24mths                              6           64
# avg_cur_bal                                   18717       958084
# bc_open_to_buy                                12383       559912
# bc_util                                        84.8        339.6
# chargeoff_within_12_mths                          0           10
# delinq_amnt                                       0       249925
# mo_sin_old_il_acct                              152          999
# mo_sin_old_rev_tl_op                            230          852
# mo_sin_rcnt_rev_tl_op                            16          438
# mo_sin_rcnt_tl                                   10          314
# mort_acc                                          3           51
# mths_since_recent_bc                             28          639
# mths_since_recent_bc_dlq                         58          202
# mths_since_recent_inq                            10           25
# mths_since_recent_revol_delinq                   52          202
# num_accts_ever_120_pd                             0           51
# num_actv_bc_tl                                    5           35
# num_actv_rev_tl                                   7           63
# num_bc_sats                                       6           63
# num_bc_tl                                        11           70
# num_il_tl                                        11          159
# num_op_rev_tl                                    10           83
# num_rev_accts                                    19          128
# num_rev_tl_bal_gt_0                               7           45
# num_sats                                         14           90
# num_tl_120dpd_2m                                  0            6
# num_tl_30dpd                                      0            4
# num_tl_90g_dpd_24m                                0           39
# num_tl_op_past_12m                                3           32
# pct_tl_nvr_dlq                                  100          100
# percent_bc_gt_75                                 75          100
# pub_rec_bankruptcies                              0           12
# tax_liens                                         0           85
# tot_hi_cred_lim                              252076        1e+07
# total_bal_ex_mort                             62548   3.4081e+06
# total_bc_limit                                28100   1.1055e+06
# total_il_high_credit_limit                    56635  2.10191e+06
# revol_bal_joint                               40771       357135
# sec_app_fico_range_low                          690          840
# sec_app_fico_range_high                         694          844
# sec_app_earliest_cr_line                        NaN          NaN
# sec_app_inq_last_6mths                            1            6
# sec_app_mort_acc                                  3           18
# sec_app_open_acc                                 15           82
# sec_app_revol_util                             78.4        212.6
# sec_app_open_act_il                               4           38
# sec_app_num_rev_accts                            17           92
# sec_app_chargeoff_within_12_mths                  0           20
# sec_app_collections_12_mths_ex_med                0           16
# sec_app_mths_since_last_major_derog              56          132
# hardship_flag                                   NaN          NaN
# hardship_type                                   NaN          NaN
# hardship_reason                                 NaN          NaN
# hardship_status                                 NaN          NaN
# deferral_term                                     3            3
# hardship_amount                              203.35       943.94
# hardship_start_date                             NaN          NaN
# hardship_end_date                               NaN          NaN
# payment_plan_start_date                         NaN          NaN
# hardship_length                                   3            3
# hardship_dpd                                     23           37
# hardship_loan_status                            NaN          NaN
# orig_projected_additional_accrued_interest  564.825      2343.15
# hardship_payoff_balance_amount              15302.4      39542.4
# hardship_last_payment_amount                267.605      1407.86
# disbursement_method                             NaN          NaN
# debt_settlement_flag                            NaN          NaN
# debt_settlement_flag_date                       NaN          NaN
# settlement_status                               NaN          NaN
# settlement_date                                 NaN          NaN
# settlement_amount                           6884.24        33601
# settlement_percentage                            50       521.35
# settlement_term                                  18          181

# %% [markdown]
# ### Dropping columns with >90% null values.

# %%
df.drop(['member_id','desc','hardship_type','hardship_reason','hardship_status','deferral_term','hardship_amount','hardship_start_date','hardship_end_date','payment_plan_start_date','hardship_length','hardship_dpd','hardship_loan_status','orig_projected_additional_accrued_interest','hardship_payoff_balance_amount','hardship_last_payment_amount','debt_settlement_flag_date','settlement_status','settlement_date','settlement_amount','settlement_percentage','settlement_term'], axis=1,inplace=True)

# %% [markdown]
# ### Dropping columns that apply to two joint applicants.

# %%
df = df[df['application_type']!='Joint App']
df.drop(['revol_bal_joint','dti_joint','verification_status_joint','sec_app_fico_range_low','sec_app_fico_range_high','sec_app_earliest_cr_line','sec_app_inq_last_6mths','sec_app_mort_acc','sec_app_open_acc','sec_app_revol_util','sec_app_open_act_il','sec_app_num_rev_accts','sec_app_chargeoff_within_12_mths','sec_app_collections_12_mths_ex_med','sec_app_mths_since_last_major_derog','annual_inc_joint','application_type'],axis=1,inplace=True)

# %% [markdown]
# ### Dropping 'funded_amnt' and 'funded_amnt_inv' since they're essentially the same as 'loan_amnt'.

# %%
df.drop(['funded_amnt','funded_amnt_inv'], axis=1,inplace=True)

# %% [markdown]
# ### Removing non-numeric characters from 'emp_length'.  "< 1 year" we'll replace with 0.

# %%
df['emp_length'].value_counts()
# Out:
# 10+ years    435633
# 2 years      119867
# 3 years      106015
# < 1 year     102544
# 1 year        87271
# 5 years       82927
# 4 years       79311
# 6 years       61920
# 8 years       60004
# 7 years       58919
# 9 years       50335
# Name: emp_length, dtype: int64

# %%
df['emp_length']=df['emp_length'].str.replace('< 1 year','0')
df['emp_length']=pd.to_numeric(df['emp_length'].str.replace('\D',''))

# %% [markdown]
# ### Removing non-numeric characters from 'term' (loan term length in months).

# %%
df['term'].value_counts()
# Out:
#  36 months    1004477
#  60 months     315033
# Name: term, dtype: int64

# %%
df['term']=pd.to_numeric(df['term'].str.replace('\D',''))

# %% [markdown]
# ### Calculating the distance between 'earliest_cr_line' (date of opening their first line of credit) and 'issue_d' (date the loan was issued) in order to see if it has predictive value.

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'],format="%b-%Y")
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'],format="%b-%Y")
df['earliest_to_loan_issue'] = ((df['issue_d'] - df['earliest_cr_line']).dt.days/365.25)

# %% [markdown]
# ### Dropping variables less relevant to predictions: 'url', 'zip_code', 'addr_state', 'initial_list_status','last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d', 'hardship_flag', 'disbursement_method', 'debt_settlement_flag', 'mths_since_last_delinq', 'mths_since_last_record', 'revol_util', 'mths_since_rcnt_il', 'il_util', 'all_util', 'avg_cur_bal', 'bc_open_to_buy', 'last_pymnt_amnt', 'last_fico_range_high', 'last_fico_range_low', 'bc_util', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'emp_title', 'mths_since_recent_inq', 'pymnt_plan', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'policy_code', 'acc_now_delinq','open_acc_6m','open_rv_12m', 'open_rv_24m', 'acc_open_past_24mths', 'num_actv_rev_tl', 'num_rev_tl_bal_gt_0', 'tot_cur_bal', 'total_bal_il', 'max_bal_bc', 'open_act_il', 'open_il_12m', 'inq_last_6mths',  'num_tl_120dpd_2m', 'num_tl_30dpd', 'inq_fi', 'total_cu_tl'

# %%
df.drop((['url', 'zip_code', 'addr_state','initial_list_status','last_pymnt_d', 'next_pymnt_d',
       'last_credit_pull_d', 'hardship_flag', 'disbursement_method', 'debt_settlement_flag', 'mths_since_last_delinq', 'mths_since_last_record', 'revol_util','mths_since_rcnt_il', 'il_util', 'all_util', 'avg_cur_bal', 'bc_open_to_buy', 'last_pymnt_amnt', 'last_fico_range_high', 'last_fico_range_low','bc_util','pct_tl_nvr_dlq','percent_bc_gt_75','emp_title','mths_since_recent_inq','pymnt_plan','out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee','recoveries','collection_recovery_fee','policy_code','acc_now_delinq','open_acc_6m','open_rv_12m', 'open_rv_24m','acc_open_past_24mths', 'num_actv_rev_tl','num_rev_tl_bal_gt_0','tot_cur_bal','total_bal_il', 'max_bal_bc', 'open_act_il', 'open_il_12m', 'inq_last_6mths',  'num_tl_120dpd_2m', 'num_tl_30dpd', 'inq_fi', 'total_cu_tl']), axis=1,inplace=True)

# %% [markdown]
# ### Dropping more specific 'sub_grade' in favor of 'grade' and creating dummies.

# %%
df.drop(['sub_grade'], axis=1, inplace=True)
df['grade'].value_counts()
# Out:
# B    386373
# C    373401
# A    231630
# D    196278
# E     91664
# F     31351
# G      8813
# Name: grade, dtype: int64

# %% [markdown]
# ### Dropping 'title' as it's a dupe of 'purpose' (reason for applying for a loan).

# %%
df.drop('title', axis=1,inplace=True)
df['purpose'].value_counts()
# Out:
# debt_consolidation    764351
# credit_card           290840
# home_improvement       85456
# other                  76429
# major_purchase         28931
# small_business         15180
# medical                15097
# car                    14380
# moving                  9289
# vacation                8934
# house                   7085
# wedding                 2294
# renewable_energy         918
# educational              326
# Name: purpose, dtype: int64

# %% [markdown]
# ### Displaying remaining categorical features.

# %%
df['home_ownership'].value_counts()
# Out:
# MORTGAGE    648107
# RENT        528509
# OWN         142418
# ANY            286
# OTHER          144
# NONE            46
# Name: home_ownership, dtype: int64

# %%
df['verification_status'].value_counts()
# Out:
# Source Verified    513873
# Verified           408334
# Not Verified       397303
# Name: verification_status, dtype: int64

# %%
df['loan_status'].value_counts()
# Out:
# Fully Paid     1057295
# Charged Off     262215
# Name: loan_status, dtype: int64

# %% [markdown]
# ### Counting null values in each column again.

# %%
(100*df[df.columns[df.isnull().any()]].isnull().sum()/len(df.index)).sort_values()
# Out:
# tax_liens                          0.002956
# collections_12_mths_ex_med         0.004244
# chargeoff_within_12_mths           0.004244
# pub_rec_bankruptcies               0.052823
# mort_acc                           3.583224
# total_bal_ex_mort                  3.583224
# total_bc_limit                     3.583224
# num_bc_sats                        4.231950
# num_sats                           4.231950
# mths_since_recent_bc               4.519329
# num_op_rev_tl                      5.117582
# num_il_tl                          5.117582
# num_bc_tl                          5.117582
# num_actv_bc_tl                     5.117582
# num_accts_ever_120_pd              5.117582
# total_il_high_credit_limit         5.117582
# mo_sin_rcnt_tl                     5.117582
# total_rev_hi_lim                   5.117582
# tot_hi_cred_lim                    5.117582
# tot_coll_amt                       5.117582
# num_tl_op_past_12m                 5.117582
# num_tl_90g_dpd_24m                 5.117582
# mo_sin_rcnt_rev_tl_op              5.117657
# mo_sin_old_rev_tl_op               5.117657
# num_rev_accts                      5.117657
# emp_length                         5.666043
# mo_sin_old_il_acct                 7.943403
# open_il_24m                       61.192185
# inq_last_12m                      61.192261
# mths_since_recent_revol_delinq    66.512721
# mths_since_last_major_derog       73.656281
# mths_since_recent_bc_dlq          76.243378
# dtype: float64

# %% [markdown]
# ### Dropping the 5.1% of rows that are all missing the same features.

# %%
df.dropna(subset=['num_rev_accts', 'mo_sin_rcnt_rev_tl_op'], inplace=True)
(100*df[df.columns[df.isnull().any()]].isnull().sum()/len(df.index)).sort_values()
# Out:
# mths_since_recent_bc               0.967427
# mo_sin_old_il_acct                 2.978240
# emp_length                         5.809673
# open_il_24m                       59.098980
# inq_last_12m                      59.099060
# mths_since_recent_revol_delinq    65.114087
# mths_since_last_major_derog       72.235361
# mths_since_recent_bc_dlq          74.962080
# dtype: float64

# %% [markdown]
# ### Filling row where 'dti' == -1 with median.

# %%
df['dti'][df['dti'] < 0] = df['emp_length'].median()

# %% [markdown]
# ### Filling these features with 0 as they measure events that are possible to not occur within these short time frames.
# #### 'open_il_24m' - Number of installment accounts opened in past 2 years.
# #### 'inq_last_12m' - Number of credit inquiries in past year.

# %%
df['open_il_24m'].fillna(value=0, inplace=True)
df['inq_last_12m'].fillna(value=0, inplace=True)

# %% [markdown]
# ### Filling these features with max since they measure the length of time since the last occurence of a bad credit event happening, and it's possible that these events have never happened.
# #### 'mths_since_last_major_derog' - Months since most recent 90-day or worse rating.
# #### 'mths_since_recent_bc_dlq' - Months since most recent bankcard delinquency.
# #### 'mths_since_recent_revol_delinq' - Months since most recent revolving delinquency.

# %%
df['mths_since_last_major_derog'].fillna(df['mths_since_last_major_derog'].max(),inplace=True)
df['mths_since_recent_bc_dlq'].fillna(df['mths_since_recent_bc_dlq'].max(),inplace=True)
df['mths_since_recent_revol_delinq'].fillna(df['mths_since_recent_revol_delinq'].max(),inplace=True)

# %% [markdown]
# ### Filling these features with median since there are few null values, and there's no intuitive way to interpret them.
# #### 'emp_length' - Current employment length in years.
# #### 'mths_since_recent_bc' - Months since most recent bankcard delinquency.
# #### 'mo_sin_old_il_acct' - Months since oldest bank installment account opened.

# %%
df['emp_length'].fillna(df['emp_length'].median(),inplace=True)
df['mths_since_recent_bc'].fillna(df['mths_since_recent_bc'].median(),inplace=True)
df['mo_sin_old_il_acct'].fillna(df['mo_sin_old_il_acct'].median(),inplace=True)

# %% [markdown]
# ### No null values left.

# %%
df[df.columns[df.isnull().any()]].isnull().sum().sort_values()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ### We'll create dummies for the categorical features.

# %%
dummies = pd.get_dummies(data=df, columns=['grade','purpose','home_ownership','verification_status', 'loan_status'], prefix=['gra','pur','hom_own','ver_sta','loan_sta'], dtype=int)

# %% [markdown]
# ## Exporting dataframe as CSV

# %%
df.to_csv( "df2.csv", encoding='utf-8', index=True)
dummies.to_csv( "dummies2.csv", encoding='utf-8', index=True)
